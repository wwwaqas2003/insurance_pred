# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv("diabetes.csv")

# %%
df.head(24)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
df.tail(24)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 744           13      153             88             37      140  40.6
# 745           12      100             84             33      105  30.0
# 746            1      147             94             41        0  49.3
# 747            1       81             74             41       57  46.3
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
plt.figure(figsize=(32,10))
sns.barplot(x='Outcome',y='Glucose',data=df,palette='Set3')
plt.title("Outcomes based on Glucose")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ADARSH\AppData\Local\Temp\ipykernel_28096\2368967458.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Outcome',y='Glucose',data=df,palette='Set3')

# %%
sns.set()
plt.figure(figsize=(8,5))
sns.distplot(df['Age'])
plt.title("age distribution")
plt.show()
# Out:
# C:\Users\ADARSH\AppData\Local\Temp\ipykernel_28096\3365756694.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %%
sns.set()
plt.figure(figsize=(8,5))
sns.distplot(df['BMI'])
plt.title("bmi distribution")
plt.show()
# Out:
# C:\Users\ADARSH\AppData\Local\Temp\ipykernel_28096\3965367698.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BMI'])

# %%
plt.figure(figsize=(8,5))
ax = sns.countplot(x='Pregnancies', data=df)
plt.title("Pregnancies Distribution")

print(ax)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
correlaion_matrix =df.corr()

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
plt.figure(figsize=(8,5))
sns.heatmap(correlaion_matrix,annot=True,cmap='coolwarm', linewidths=5)
plt.title("correlation matrix")
plt.show()

# %%
x=df.drop(columns='Outcome',axis=1)

# %%
y=df['Outcome']

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
regression=LogisticRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
training_data_prediction=regression.predict(x_train)

# %%
r2_train=metrics.accuracy_score(y_train,training_data_prediction)

# %%
r2_train
# Out:
# 0.7768729641693811

# %%
testing_data_prediction=regression.predict(x_test)

# %%
r2_test=metrics.accuracy_score(y_test,testing_data_prediction)

# %%
r2_test
# Out:
# 0.7662337662337663

# %%
regression_rd=RandomForestClassifier()

# %%
regression_rd.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
train_data_predict=regression_rd.predict(x_train)

# %%
r2=metrics.accuracy_score(y_train,train_data_predict)

# %%
r2
# Out:
# 1.0

# %%
test_data_predict=regression_rd.predict(x_test)

# %%
r3=metrics.accuracy_score(y_test,test_data_predict)

# %%
r3
# Out:
# 0.7532467532467533

# %%
import joblib

# %%
joblib.dump(regression,"diabetes_model.joblib")
# Out:
# ['diabetes_model.joblib']

# %%
print("model saved as 'diabetes_model.joblib'")
# Out:
# model saved as 'diabetes_model.joblib'

# %%
joblib.dump(regression_rd,"rd_diabetes.joblib")
# Out:
# ['rd_diabetes.joblib']

# %%
print("RD model saved as 'rd_diabetes.joblib'")
# Out:
# RD model saved as 'rd_diabetes.joblib'
